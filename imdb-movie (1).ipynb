# %% [markdown]
#  **Python Sprint1Project- Data Analysis on IMDB Movie**
#
# Problem Statement:The project is about finding out the various insights in IMDB Movies dataset. We analyze this data and some following question like clean the data, find the movies with the highest profit , find top 10 directors, find in which year highest avg voting etc.

# %%
# import necessary library for data manipulation, analysis, and visualization

import numpy as np # numerical operations
import pandas as pd # data analysis
import matplotlib.pyplot as plt # visualizations
import seaborn as sns

# %%
#Reading data from '../input/imdb-data/IMDB-Movie-Data.csv' file.
data= pd.read_csv('../input/imdb-data/IMDB-Movie-Data.csv', sep =',')

# %%
#show the frist 5 rows 
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# **Inference**
# using head() we can see top 5 rows of dataset.

# %%
#show the last 5 rows 
data.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %% [markdown]
# **Inference-**
# Using tail() we can see last 5 rows of dataset.

# %%
#How many rows and columns
data.shape
# Out:
# (1000, 12)

# %% [markdown]
# **Inference-**
# using shape attribute of pandas dataframe we find shape of our dataset means no. of rows is 1000 and no. of columns is 12.

# %%
# Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# **Inference-**
# In our dataset we have 3 column with floating datatype, 4 column with integer datatype, and 5 column with object datatype and memory used 93.9+ KB requirement for our dataset.

# %%
#Check Missing Values In The Dataset
data.isnull().sum()
pre_missing=data.isnull().sum()*100/len(data)
pre_missing
# Out:
# Rank                   0.0
# Title                  0.0
# Genre                  0.0
# Description            0.0
# Director               0.0
# Actors                 0.0
# Year                   0.0
# Runtime (Minutes)      0.0
# Rating                 0.0
# Votes                  0.0
# Revenue (Millions)    12.8
# Metascore              6.4
# dtype: float64

# %% [markdown]
# **Inference-**
# As we can see overhere around 13% value are missing in revenue and around 7% value are missing in metascore.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# **Inference-**
# As we can see that now it is displaying heatmap. As we can see that heatmap is showing some missing value in lighter colour revenue and metascore columns. So, this way we can visualize missing value.

# %%
#Drop All the Missing Values
data.dropna(how='any',inplace=True)

# %%
#check the missing anther time
data.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %% [markdown]
# **Infrence-**
# As we can see missing value are drop. So, this way we can drop all the missing value using dropna() .

# %%
#Check For Duplicate Data
dup=data.duplicated().any()
print("Any duplicate Value?",dup)
# Out:
# Any duplicate Value? False

# %% [markdown]
# **Inference-**
# we can see that there is no duplicate value in our dataset. If it is there then we can drop .

# %%
# Overall Statistics About The DataFrame
data.describe()
# Out:
#               Rank        Year  Runtime (Minutes)      Rating         Votes  \
# count   838.000000   838.00000         838.000000  838.000000  8.380000e+02
# mean    485.247017  2012.50716         114.638425    6.814320  1.932303e+05
# std     286.572065     3.17236          18.470922    0.877754  1.930990e+05
# min       1.000000  2006.00000          66.000000    1.900000  1.780000e+02
# 25%     238.250000  2010.00000         101.000000    6.300000  6.127650e+04
# 50%     475.500000  2013.00000         112.000000    6.900000  1.368795e+05
# 75%     729.750000  2015.00000         124.000000    7.500000  2.710830e+05
# max    1000.000000  2016.00000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          838.000000  838.000000
# mean            84.564558   59.575179
# std            104.520227   16.952416
# min              0.000000   11.000000
# 25%             13.967500   47.000000
# 50%             48.150000   60.000000
# ...

# %% [markdown]
# **Inference-**
# We can see min and max value in year shows min and max release years. The dataset contain movies from 2006 to 2016. Avg rating is about 6.8 , min rating is 1.9 and max rating is 9.0 We can see the maximum revenue earn by movie is 936.630000

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %% [markdown]
# **Inference-**
# Let me first display column name using data.coumns to know actually we have to work on which column after executing it is displaying column name .

# %%
#Title of The Movie Having Runtime Greater Than or equal to 185 Minutes
data[data['Runtime (Minutes)']>=185]
# Out:
#     Rank              Title                Genre  \
# 88    89  The Hateful Eight  Crime,Drama,Mystery
#
#                                           Description           Director  \
# 88  In the dead of a Wyoming winter, a bounty hunt...  Quentin Tarantino
#
#                                                Actors  Year  \
# 88  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...  2015
#
#     Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 88                187     7.8  341170               54.12       68.0

# %% [markdown]
# **Inference-**
# we use runtime(minutes) column and here we do filtering . after executing it is displaying title of movies having >=185 minutes.

# %%
data[data['Runtime (Minutes)']>=185]['Title']
# Out:
# 88    The Hateful Eight
# Name: Title, dtype: object

# %%
#Which Year There Was The Highest Average Voting?
data.groupby('Year')['Votes'].mean().sort_values(ascending=False)
# Out:
# Year
# 2012    290861.483871
# 2006    277232.219512
# 2009    267180.577778
# 2008    266580.145833
# 2007    266530.704545
# 2010    261082.929825
# 2011    259254.736842
# 2013    225531.892857
# 2014    211926.881720
# 2015    129512.651376
# 2016     68437.823232
# Name: Votes, dtype: float64

# %% [markdown]
# **Inference-**
# After executing it is showing highest voting is in year 2012. we use sort_value to sort in ascending order.To sort in descending order we have use sort_values(ascending=False).

# %%
# we can visualize this using seaborn barplot.
plt.figure(figsize=(17,8))
sns.barplot(x='Year',y='Votes',data=data)
plt.title("Votes By Year")
plt.show()

# %% [markdown]
# **Inference-**
# As we can see that highest avg voting is in year 2012. we can use barplot for displaying relationship between categorical dta and atleast one numerical variable.

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %% [markdown]
# **Inference-** Let me first display column name using data.coumns to know actually we have to work on which column after executing it is displaying column name .

# %%
#In Which Year There Was The Highest Average Revenue?
data.groupby('Year')['Revenue (Millions)'].mean().sort_values(ascending=False)
# Out:
# Year
# 2009    115.742000
# 2012    110.103065
# 2010    105.081579
# 2008     97.525417
# 2011     93.703333
# 2007     93.074091
# 2013     88.084643
# 2006     87.255610
# 2014     85.433656
# 2015     80.725596
# 2016     55.566111
# Name: Revenue (Millions), dtype: float64

# %% [markdown]
# **Inference-**
# We use Revenue(Millions) column.After executing it is showing highest revenue is in year 2009. we use sort_value to sort in ascending order. To sort in descending order we have use sort_values(ascending=False).

# %%
plt.figure(figsize=(17,8))
sns.barplot(x='Year',y='Revenue (Millions)',data=data)
plt.title("Revenue By Year")
plt.show()

# %% [markdown]
# **Inference-**
# We can see that highest avg revenue was in year 2009.

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %% [markdown]
# **Inference-** Let me first display column name using data.coumns to know actually we have to work on which column after executing it is displaying column name .

# %%
#The Average Rating For Each Director
data1=data.groupby('Director')['Rating'].mean().reset_index()
data1
# Out:
#                 Director  Rating
# 0             Aamir Khan    8.50
# 1    Abdellatif Kechiche    7.80
# 2             Adam McKay    7.00
# 3          Adam Shankman    6.30
# 4           Adam Wingard    5.90
# ..                   ...     ...
# 519         Xavier Dolan    8.10
# 520          Yimou Zhang    6.10
# 521     Yorgos Lanthimos    7.20
# 522          Zack Snyder    7.04
# 523        Zackary Adler    5.10
#
# [524 rows x 2 columns]

# %% [markdown]
# **Inference-**
# We use director and rating column to find average rating for each director.

# %%
#The top ten Director by Average  Rating 
top_10=data1.sort_values(by="Rating" ,ascending=False).head(10)

top_10
# Out:
#                              Director  Rating
# 88                  Christopher Nolan    8.68
# 378                   Olivier Nakache    8.60
# 318                    Makoto Shinkai    8.60
# 154  Florian Henckel von Donnersmarck    8.50
# 0                          Aamir Khan    8.50
# 97                    Damien Chazelle    8.40
# 408                   Rajkumar Hirani    8.30
# 490                 Thomas Vinterberg    8.30
# 305                       Lee Unkrich    8.30
# 393                       Pete Docter    8.25

# %% [markdown]
# **Inference-**
# Here we can see that we sort in descending order according to rating . we see top 10 director by avg rating.

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %% [markdown]
# **Inference-** Let me first display column name using data.coumns to know actually we have to work on which column after executing it is displaying column name .

# %%
#number of Movies in the year
df=data.groupby('Year')['Title'].count().reset_index()
df
# Out:
#     Year  Title
# 0   2006     41
# 1   2007     44
# 2   2008     48
# 3   2009     45
# 4   2010     57
# 5   2011     57
# 6   2012     62
# 7   2013     84
# 8   2014     93
# 9   2015    109
# 10  2016    198

# %% [markdown]
# **Inference-**
# We use year and title column to find the number of movies in the year.

# %%
data['Year'].value_counts()
# Out:
# 2016    198
# 2015    109
# 2014     93
# 2013     84
# 2012     62
# 2011     57
# 2010     57
# 2008     48
# 2009     45
# 2007     44
# 2006     41
# Name: Year, dtype: int64

# %% [markdown]
# **Inference-**
# we see that no. of movies release per year using value_counts().

# %%
sns.countplot(x='Year',data=data)
plt.title("Number of Movies Per Year")
plt.show()

# %% [markdown]
# **Inference-**
# For this we use seaborn countplot. After executing this way we can display no. of movies per year.

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %% [markdown]
# **Inference-** Let me first display column name using data.coumns to know actually we have to work on which column after executing it is displaying column name .

# %%
#Find Most Popular Movie Title 
data[data['Revenue (Millions)'].max()==data['Revenue (Millions)']]['Title']
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# Name: Title, dtype: object

# %%
#Find Most worest Movie Title 
data[data['Revenue (Millions)'].min()==data['Revenue (Millions)']]['Title']
# Out:
# 231    A Kind of Murder
# Name: Title, dtype: object

# %%
#Top 10 Highest Rated Movie Titles And its Directors
top_10=data.sort_values(by='Rating',ascending=False).head(10)
top_10
# Out:
#      Rank                  Title                    Genre  \
# 54     55        The Dark Knight       Action,Crime,Drama
# 80     81              Inception  Action,Adventure,Sci-Fi
# 36     37           Interstellar   Adventure,Drama,Sci-Fi
# 249   250       The Intouchables   Biography,Comedy,Drama
# 96     97          Kimi no na wa  Animation,Drama,Fantasy
# 124   125  The Dark Knight Rises          Action,Thriller
# 991   992       Taare Zameen Par       Drama,Family,Music
# 133   134               Whiplash              Drama,Music
# 99    100           The Departed     Crime,Drama,Thriller
# 476   477    The Lives of Others           Drama,Thriller
#
#                                            Description  \
# 54   When the menace known as the Joker wreaks havo...
# 80   A thief, who steals corporate secrets through ...
# 36   A team of explorers travel through a wormhole ...
# 249  After he becomes a quadriplegic from a paragli...
# ...

# %% [markdown]
# **Inference-**
# Here we see that top 10 Highest Rated Movie Titles And its Directors.we use sort_value to sort in ascending order.To sort in descending order we have use sort_values(ascending=False).we sort in descending order by rating.

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
# Average Rating of Movies Year Wise
df=data.groupby('Year')['Rating'].mean().reset_index()
df
# Out:
#     Year    Rating
# 0   2006  7.143902
# 1   2007  7.140909
# 2   2008  6.708333
# 3   2009  6.911111
# 4   2010  6.894737
# 5   2011  6.945614
# 6   2012  6.933871
# 7   2013  6.832143
# 8   2014  6.822581
# 9   2015  6.674312
# 10  2016  6.644444

# %% [markdown]
# **Inference-**
# we have to work on rating column. we can see that average rating year wise

# %%
#Does Rating Affect The Revenue?
data.corr()
# Out:
#                         Rank      Year  Runtime (Minutes)    Rating     Votes  \
# Rank                1.000000 -0.312809          -0.254783 -0.243125 -0.303284
# Year               -0.312809  1.000000          -0.101933 -0.145703 -0.362445
# Runtime (Minutes)  -0.254783 -0.101933           1.000000  0.374566  0.399298
# Rating             -0.243125 -0.145703           0.374566  1.000000  0.517452
# Votes              -0.303284 -0.362445           0.399298  0.517452  1.000000
# Revenue (Millions) -0.273170 -0.129198           0.281721  0.217106  0.636833
# Metascore          -0.195909 -0.062303           0.221397  0.672731  0.332674
#
#                     Revenue (Millions)  Metascore
# Rank                         -0.273170  -0.195909
# Year                         -0.129198  -0.062303
# Runtime (Minutes)             0.281721   0.221397
# Rating                        0.217106   0.672731
# Votes                         0.636833   0.332674
# ...

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x="Rating",y="Revenue (Millions)",data=data)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Revenue (Millions)'>

# %% [markdown]
# **Inference-**
# As we can see overhere scatterplot.By, this scatterplot we can say that yes rating does affect the revenue . Rating is high and revenue is also high.

# %%
#Count Number of Action Movies
data[data['Genre'].str.contains('Action',case=False)]
# Out:
#      Rank                           Title                       Genre  \
# 0       1         Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 4       5                   Suicide Squad    Action,Adventure,Fantasy
# 5       6                  The Great Wall    Action,Adventure,Fantasy
# 8       9              The Lost City of Z  Action,Adventure,Biography
# 12     13                       Rogue One     Action,Adventure,Sci-Fi
# ..    ...                             ...                         ...
# 954   955                      Death Race      Action,Sci-Fi,Thriller
# 956   957                          Legion       Action,Fantasy,Horror
# 958   959                  3 Days to Kill       Action,Drama,Thriller
# 990   991  Underworld: Rise of the Lycans    Action,Adventure,Fantasy
# 993   994        Resident Evil: Afterlife     Action,Adventure,Horror
#
#                                            Description            Director  \
# ...

# %%
 len(data[data['Genre'].str.contains('Action',case=False)])
# Out:
# 277

# %%
#Count Number of Drama Movies
len(data[data['Genre'].str.contains('Drama',case=False)])
# Out:
# 419

# %%
#Count Number of Comedy Movies 
len(data[data['Genre'].str.contains('Comedy',case=False)])
# Out:
# 250

# %% [markdown]
# **Conclusion-**
# Based  on analysis it is observed that  The dataset contain movies from 2006 to 2016. We can see the maximum revenue earn by movie is 936.630000
# IMDb is like a big online library where you can find information about movies and TV shows. It's a place where people share their thoughts and ratings for different films. So, in simple terms, IMDb is a handy tool for discovering, learning about, and deciding whether to watch a movie or show based on what others think about it. It's like a movie guide created by the people, for the people.
